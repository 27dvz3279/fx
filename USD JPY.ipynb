# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([1, 2, 3, 4, 5, 6, 7])
gene_1 = np.array([121.52, 121.52, 121.52, 121.52, 121.52, 121.52, 121.52])
gene_2 = np.array([105.67, 105.67, 105.67, 105.67, 105.67, 105.67, 105.67])
gene_3 = np.array([89.819, 89.819, 89.819, 89.819, 89.819, 89.819, 89.819])
gene_4 = np.array([109.30, 110.00, 107.42, 107.77, 107.18, 107.67, 106.73])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='USD JPY')

plt.legend()
plt.xlabel("2020")
plt.ylabel("value")
plt.ylim(80, 130)
plt.show()
