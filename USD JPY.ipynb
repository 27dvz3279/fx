# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([6, 7, 8, 9, 10, 11, 12, 13])
gene_1 = np.array([121.85, 121.85, 121.85, 121.85, 121.85, 121.85, 121.85, 121.85])
gene_2 = np.array([105.96, 105.96, 105.96, 105.96, 105.96, 105.96, 105.96, 105.96])
gene_3 = np.array([90.066, 90.066, 90.066, 90.066, 90.066, 90.066, 90.066, 90.066])
gene_4 = np.array([110.09, 110.26, 109.84, 110.14, 113.10, 113.96, 113.94, 114.89])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='USD JPY')

plt.legend()
plt.xlabel("2022")
plt.ylabel("value")
plt.ylim(80, 130)
plt.show()
