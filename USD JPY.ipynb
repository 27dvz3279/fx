# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([7, 8, 9, 10, 11, 12, 13, 14, 15])
gene_1 = np.array([134.15, 134.15, 134.15, 134.15, 134.15, 134.15, 134.15, 134.15, 134.15])
gene_2 = np.array([116.65, 116.65, 116.65, 116.65, 116.65, 116.65, 116.65, 116.65, 116.65])
gene_3 = np.array([99.153, 99.153, 99.153, 99.153, 99.153, 99.153, 99.153, 99.153, 99.153])
gene_4 = np.array([146.73, 147.66, 147.84, 151.42, 155.13, 155.87, 156.71, 155.08, 158.63])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='USD JPY')

plt.legend()
plt.xlabel("2026")
plt.ylabel("value")
plt.ylim(80, 160)
plt.show()
