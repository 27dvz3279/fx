# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([1, 2, 3, 4, 5, 6, 7, 8])
gene_1 = np.array([122.68, 122.68, 122.68, 122.68, 122.68, 122.68, 122.68, 122.68])
gene_2 = np.array([106.68, 106.68, 106.68, 106.68, 106.68, 106.68, 106.68, 106.68])
gene_3 = np.array([90.678, 90.678, 90.678, 90.678, 90.678, 90.678, 90.678, 90.678])
gene_4 = np.array([114.89, 115.16, 118.61, 126.28, 128.77, 133.85, 136.69, 135.11])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='USD JPY')

plt.legend()
plt.xlabel("2022")
plt.ylabel("value")
plt.ylim(80, 150)
plt.show()
