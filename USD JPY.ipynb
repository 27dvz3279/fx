# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([1, 2, 3, 4, 5, 6])
gene_1 = np.array([125.28, 125.28, 125.28, 125.28, 125.28, 125.28])
gene_2 = np.array([108.94, 108.94, 108.94, 108.94, 108.94, 108.94])
gene_3 = np.array([92.599, 92.599, 92.599, 92.599, 92.599, 92.599])
gene_4 = np.array([130.39, 132.84, 133.69, 133.40, 136.99, 141.24])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='USD JPY')

plt.legend()
plt.xlabel("2023")
plt.ylabel("value")
plt.ylim(80, 150)
plt.show()
