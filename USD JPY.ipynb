# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([7, 8, 9, 10, 11, 12, 13])
gene_1 = np.array([133.62, 133.62, 133.62, 133.62, 133.62, 133.62, 133.62])
gene_2 = np.array([116.19, 116.19, 116.19, 116.19, 116.19, 116.19, 116.19])
gene_3 = np.array([98.762, 98.762, 98.762, 98.762, 98.762, 98.762, 98.762])
gene_4 = np.array([146.73, 147.66, 147.84, 151.42, 155.13, 155.87, 156.71])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='USD JPY')

plt.legend()
plt.xlabel("2026")
plt.ylabel("value")
plt.ylim(80, 160)
plt.show()
