# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([1, 2, 3, 4, 5, 6])
gene_1 = np.array([132.05, 132.05, 132.05, 132.05, 132.05, 132.05])
gene_2 = np.array([114.83, 114.83, 114.83, 114.83, 114.83, 114.83])
gene_3 = np.array([97.606, 97.606, 97.606, 97.606, 97.606, 97.606])
gene_4 = np.array([156.39, 151.79, 149.06, 144.08, 144.65, 144.50])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='USD JPY')

plt.legend()
plt.xlabel("2025")
plt.ylabel("value")
plt.ylim(80, 160)
plt.show()
