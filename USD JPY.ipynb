# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([7, 8, 9, 10, 11, 12, 13])
gene_1 = np.array([127.13, 127.13, 127.13, 127.13, 127.13, 127.13, 127.13])
gene_2 = np.array([110.55, 110.55, 110.55, 110.55, 110.55, 110.55, 110.55])
gene_3 = np.array([93.968, 93.968, 93.968, 93.968, 93.968, 93.968, 93.968])
gene_4 = np.array([140.96, 144.75, 147.62, 149.58, 149.83, 144.01, 146.01])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='USD JPY')

plt.legend()
plt.xlabel("2023")
plt.ylabel("value")
plt.ylim(80, 160)
plt.show()
