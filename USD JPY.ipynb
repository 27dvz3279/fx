# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([7, 8, 9, 10, 11, 12, 13])
gene_1 = np.array([130.69, 130.69, 130.69, 130.69, 130.69, 130.69, 130.69])
gene_2 = np.array([113.64, 113.64, 113.64, 113.64, 113.64, 113.64, 113.64])
gene_3 = np.array([96.594, 96.594, 96.594, 96.594, 96.594, 96.594, 96.594])
gene_4 = np.array([157.81, 146.19, 143.16, 149.55, 153.60, 153.82, 156.39])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='USD JPY')

plt.legend()
plt.xlabel("2025")
plt.ylabel("value")
plt.ylim(80, 160)
plt.show()
