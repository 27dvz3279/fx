# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([6, 7, 8, 9, 10, 11, 12, 13])
gene_1 = np.array([121.57, 121.57, 121.57, 121.57, 121.57, 121.57, 121.57, 121.57])
gene_2 = np.array([105.71, 105.71, 105.71, 105.71, 105.71, 105.71, 105.71, 105.71])
gene_3 = np.array([89.854, 89.854, 89.854, 89.854, 89.854, 89.854, 89.854, 89.854])
gene_4 = np.array([107.67, 106.73, 105.98, 105.56, 105.17, 104.37, 103.81, 103.73])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='USD JPY')

plt.legend()
plt.xlabel("2021")
plt.ylabel("value")
plt.ylim(80, 130)
plt.show()
