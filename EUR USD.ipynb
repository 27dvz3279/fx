# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([1, 2, 3, 4, 5, 6, 7])
gene_1 = np.array([1.3360, 1.3360, 1.3360, 1.3360, 1.3360, 1.3360, 1.3360])
gene_2 = np.array([1.1617, 1.1617, 1.1617, 1.1617, 1.1617, 1.1617, 1.1617])
gene_3 = np.array([0.9874, 0.9874, 0.9874, 0.9874, 0.9874, 0.9874, 0.9874])
gene_4 = np.array([1.0354, 1.0411, 1.0804, 1.1229, 1.1281, 1.1508, 1.1684])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='EUR USD')

plt.legend()
plt.xlabel("2025")
plt.ylabel("value")
plt.ylim(0.8, 1.45)
plt.show()
