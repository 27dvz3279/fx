# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([7, 8, 9, 10, 11, 12, 13])
gene_1 = np.array([1.3357, 1.3357, 1.3357, 1.3357, 1.3357, 1.3357, 1.3357])
gene_2 = np.array([1.1615, 1.1615, 1.1615, 1.1615, 1.1615, 1.1615, 1.1615])
gene_3 = np.array([0.9873, 0.9873, 0.9873, 0.9873, 0.9873, 0.9873, 0.9873])
gene_4 = np.array([1.1684, 1.1630, 1.1734, 1.1636, 1.1552, 1.1712, 1.1734])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='EUR USD')

plt.legend()
plt.xlabel("2026")
plt.ylabel("value")
plt.ylim(0.8, 1.45)
plt.show()
