# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([1, 2, 3, 4, 5, 6])
gene_1 = np.array([1.3529, 1.3529, 1.3529, 1.3529, 1.3529, 1.3529])
gene_2 = np.array([1.1764, 1.1764, 1.1764, 1.1764, 1.1764, 1.1764])
gene_3 = np.array([0.9999, 0.9999, 0.9999, 0.9999, 0.9999, 0.9999])
gene_4 = np.array([1.0772, 1.0715, 1.0701, 1.0963, 1.0867, 1.0835])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='EUR USD')

plt.legend()
plt.xlabel("2023")
plt.ylabel("value")
plt.ylim(0.8, 1.45)
plt.show()
