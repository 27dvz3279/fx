# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([1, 2, 3, 4, 5, 6])
gene_1 = np.array([1.3445, 1.3445, 1.3445, 1.3445, 1.3445, 1.3445])
gene_2 = np.array([1.1691, 1.1691, 1.1691, 1.1691, 1.1691, 1.1691])
gene_3 = np.array([0.9937, 0.9937, 0.9937, 0.9937, 0.9937, 0.9937])
gene_4 = np.array([1.0907, 1.0789, 1.0867, 1.0730, 1.0806, 1.0758])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='EUR USD')

plt.legend()
plt.xlabel("2024")
plt.ylabel("value")
plt.ylim(0.8, 1.45)
plt.show()
