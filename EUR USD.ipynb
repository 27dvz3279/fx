# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([7, 8, 9, 10, 11, 12])
gene_1 = np.array([1.3487, 1.3487, 1.3487, 1.3487, 1.3487, 1.3487])
gene_2 = np.array([1.1728, 1.1728, 1.1728, 1.1728, 1.1728, 1.1728])
gene_3 = np.array([0.9969, 0.9969, 0.9969, 0.9969, 0.9969, 0.9969])
gene_4 = np.array([1.1061, 1.0908, 1.0689, 1.0560, 1.0801, 1.0913])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='EUR USD')

plt.legend()
plt.xlabel("2023")
plt.ylabel("value")
plt.ylim(0.8, 1.45)
plt.show()
