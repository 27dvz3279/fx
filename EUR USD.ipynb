# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([6, 7, 8, 9, 10, 11, 12, 13, 14])
gene_1 = np.array([1.3567, 1.3567, 1.3567, 1.3567, 1.3567, 1.3567, 1.3567, 1.3567, 1.3567])
gene_2 = np.array([1.1797, 1.1797, 1.1797, 1.1797, 1.1797, 1.1797, 1.1797, 1.1797, 1.1797])
gene_3 = np.array([1.0027, 1.0027, 1.0027, 1.0027, 1.0027, 1.0027, 1.0027, 1.0027, 1.0027])
gene_4 = np.array([1.0574, 1.0182, 1.0128, 0.9907, 0.9825, 1.0192, 1.0584, 1.0772, 1.0715])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='EUR USD')

plt.legend()
plt.xlabel("2023")
plt.ylabel("value")
plt.ylim(0.8, 1.45)
plt.show()
