# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
 
plt.style.use('default')
sns.set()
sns.set_style('darkgrid')
sns.set_palette('bright')

x = np.array([1, 2, 3, 4, 5, 6, 7, 8])
gene_1 = np.array([1.3728, 1.3728, 1.3728, 1.3728, 1.3728, 1.3728, 1.3728, 1.13728])
gene_2 = np.array([1.1947, 1.1947, 1.1947, 1.1947, 1.1947, 1.1947, 1.1947])
gene_3 = np.array([1.0146, 1.0146, 1.0146, 1.0146, 1.0155, 1.0155, 1.0155])
gene_4 = np.array([1.1098, 1.0910, 1.1062, 1.0867, 1.0896, 1.1254, 1.1456])

plt.plot(x, gene_1, label='top')
plt.plot(x, gene_2, label='avg')
plt.plot(x, gene_3, label='bottom')
plt.plot(x, gene_4, label='EUR USD')

plt.legend()
plt.xlabel("2020")
plt.ylabel("value")
plt.ylim(1.0, 1.45)
plt.show()
